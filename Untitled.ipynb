# %% [markdown]
# ### 'importing the dataset'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Data_file.xlsx - Data.csv')
df1=pd.read_csv('Test_data_file.xlsx - Prediction.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0        NaN        NaN        NaN        NaN           NaN
# 1      S.No.    College       Role  City type  Previous CTC
# 2          1     Tier 1    Manager  Non-Metro    55,523.00
# 3          2     Tier 2  Executive      Metro    57,081.00
# 4          3     Tier 2  Executive      Metro    60,347.00
#
#              Unnamed: 5        Unnamed: 6    Unnamed: 7    Unnamed: 8
# 0                   NaN               NaN           NaN           NaN
# 1  Previous job changes  Graduation marks  Exp (Months)           CTC
# 2                     3                66            19    71,406.58
# 3                     1                84            18    68,005.87
# 4                     2                52            28    76,764.02

# %%
df1.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
df.info()#checking the info of the train dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1339 non-null   object
#  1   Unnamed: 1  1339 non-null   object
#  2   Unnamed: 2  1339 non-null   object
#  3   Unnamed: 3  1339 non-null   object
#  4   Unnamed: 4  1339 non-null   object
#  5   Unnamed: 5  1339 non-null   object
#  6   Unnamed: 6  1339 non-null   object
#  7   Unnamed: 7  1339 non-null   object
#  8   Unnamed: 8  1339 non-null   object
# dtypes: object(9)
# memory usage: 94.3+ KB

# %%
df1.info()#checking the info of the test dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   College_T1            1338 non-null   int64
#  4   College_T2            1338 non-null   int64
#  5   Role_Manager          1338 non-null   int64
#  6   City_Metro            1338 non-null   int64
#  7   previous CTC          1338 non-null   int64
#  8   previous job changes  1338 non-null   int64
#  9   Graduation marks      1338 non-null   int64
#  10  Exp                   1338 non-null   int64
#  11  Actual CTC            1338 non-null   float64
#  12  Predicted CTC         0 non-null      float64
#  13  Unnamed: 13           0 non-null      float64
#  14  Unnamed: 14           0 non-null      float64
# ...

# %%
df.isnull().sum()#checking null values in train data
# Out:
# Unnamed: 0    1
# Unnamed: 1    1
# Unnamed: 2    1
# Unnamed: 3    1
# Unnamed: 4    1
# Unnamed: 5    1
# Unnamed: 6    1
# Unnamed: 7    1
# Unnamed: 8    1
# dtype: int64

# %%
df1.isnull().sum()#checking null values in test data
# Out:
# College                    0
# Role                       0
# City type                  0
# College_T1                 0
# College_T2                 0
# Role_Manager               0
# City_Metro                 0
# previous CTC               0
# previous job changes       0
# Graduation marks           0
# Exp                        0
# Actual CTC                 0
# Predicted CTC           1338
# Unnamed: 13             1338
# Unnamed: 14             1338
# Unnamed: 15             1337
# Unnamed: 16             1337
# Unnamed: 17             1337
# Unnamed: 18             1337
# Unnamed: 19             1337
# Unnamed: 20             1337
# Unnamed: 21             1337
# Unnamed: 22             1337
# Unnamed: 23             1337
# dtype: int64

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0        NaN        NaN        NaN        NaN           NaN
# 1      S.No.    College       Role  City type  Previous CTC
# 2          1     Tier 1    Manager  Non-Metro    55,523.00
# 3          2     Tier 2  Executive      Metro    57,081.00
# 4          3     Tier 2  Executive      Metro    60,347.00
#
#              Unnamed: 5        Unnamed: 6    Unnamed: 7    Unnamed: 8
# 0                   NaN               NaN           NaN           NaN
# 1  Previous job changes  Graduation marks  Exp (Months)           CTC
# 2                     3                66            19    71,406.58
# 3                     1                84            18    68,005.87
# 4                     2                52            28    76,764.02

# %%
df.drop(index=0,inplace=True)#dropping the null values

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 1      S.No.    College       Role  City type  Previous CTC
# 2          1     Tier 1    Manager  Non-Metro    55,523.00
# 3          2     Tier 2  Executive      Metro    57,081.00
# 4          3     Tier 2  Executive      Metro    60,347.00
# 5          4     Tier 3  Executive      Metro    49,010.00
#
#              Unnamed: 5        Unnamed: 6    Unnamed: 7    Unnamed: 8
# 1  Previous job changes  Graduation marks  Exp (Months)           CTC
# 2                     3                66            19    71,406.58
# 3                     1                84            18    68,005.87
# 4                     2                52            28    76,764.02
# 5                     2                81            33    82,092.39

# %%
df.isnull().sum()#checking any null values after dropping the null values
# Out:
# Unnamed: 0    0
# Unnamed: 1    0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# Unnamed: 5    0
# Unnamed: 6    0
# Unnamed: 7    0
# Unnamed: 8    0
# dtype: int64

# %%
df.rename(columns={'Unnamed: 1':'College','Unnamed: 2': 'Role','Unnamed: 3':'City type',
                   'Unnamed: 4':'Previous CTC','Unnamed: 5':'Previous job changes',
                   'Unnamed: 6':'Graduation marks','Unnamed: 7':'Exp (Months)',
                   'Unnamed: 8':'CTC'
                       },inplace=True)#changing the columns name

# %%
df.drop(index=1,axis=1,inplace=True)
df.drop('Unnamed: 0',axis=1,inplace=True)#dropping the unneccesary column

# %%
df.columns
# Out:
# Index(['College', 'Role', 'City type', 'Previous CTC', 'Previous job changes',
#        'Graduation marks', 'Exp (Months)', 'CTC'],
#       dtype='object')

# %%
df1.isnull().sum()#checking null values in test data
# Out:
# College                    0
# Role                       0
# City type                  0
# College_T1                 0
# College_T2                 0
# Role_Manager               0
# City_Metro                 0
# previous CTC               0
# previous job changes       0
# Graduation marks           0
# Exp                        0
# Actual CTC                 0
# Predicted CTC           1338
# Unnamed: 13             1338
# Unnamed: 14             1338
# Unnamed: 15             1337
# Unnamed: 16             1337
# Unnamed: 17             1337
# Unnamed: 18             1337
# Unnamed: 19             1337
# Unnamed: 20             1337
# Unnamed: 21             1337
# Unnamed: 22             1337
# Unnamed: 23             1337
# dtype: int64

# %%
df1['Unnamed: 15'].unique
# Out:
# <bound method Series.unique of 0               NaN
# 1       32438.76192
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 1333            NaN
# 1334            NaN
# 1335            NaN
# 1336            NaN
# 1337            NaN
# Name: Unnamed: 15, Length: 1338, dtype: float64>

# %%
df1['Unnamed: 15'].isnull().sum()#checking null values column wise
# Out:
# 1337

# %%
df1['Unnamed: 15'].unique
# Out:
# <bound method Series.unique of 0               NaN
# 1       32438.76192
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 1333            NaN
# 1334            NaN
# 1335            NaN
# 1336            NaN
# 1337            NaN
# Name: Unnamed: 15, Length: 1338, dtype: float64>

# %%
df1['Unnamed: 13'].isnull().sum()
# Out:
# 1338

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   College_T1            1338 non-null   int64
#  4   College_T2            1338 non-null   int64
#  5   Role_Manager          1338 non-null   int64
#  6   City_Metro            1338 non-null   int64
#  7   previous CTC          1338 non-null   int64
#  8   previous job changes  1338 non-null   int64
#  9   Graduation marks      1338 non-null   int64
#  10  Exp                   1338 non-null   int64
#  11  Actual CTC            1338 non-null   float64
#  12  Predicted CTC         0 non-null      float64
#  13  Unnamed: 13           0 non-null      float64
#  14  Unnamed: 14           0 non-null      float64
# ...

# %%
df1.drop(df1.loc[:,'Predicted CTC':'Unnamed: 23'].columns,axis=1,inplace=True)#dropping the null values columns

# %%
df1.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC
# 0  71406.57653
# 1  68005.87063
# 2  76764.02028
# 3  82092.38688
# 4  73878.09773

# %%
df.head()
# Out:
#   College       Role  City type  Previous CTC Previous job changes  \
# 2  Tier 1    Manager  Non-Metro    55,523.00                     3
# 3  Tier 2  Executive      Metro    57,081.00                     1
# 4  Tier 2  Executive      Metro    60,347.00                     2
# 5  Tier 3  Executive      Metro    49,010.00                     2
# 6  Tier 3  Executive      Metro    57,879.00                     4
#
#   Graduation marks Exp (Months)           CTC
# 2               66           19    71,406.58
# 3               84           18    68,005.87
# 4               52           28    76,764.02
# 5               81           33    82,092.39
# 6               74           32    73,878.10

# %% [markdown]
# ### visualzation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#   College       Role  City type  Previous CTC Previous job changes  \
# 2  Tier 1    Manager  Non-Metro    55,523.00                     3
# 3  Tier 2  Executive      Metro    57,081.00                     1
# 4  Tier 2  Executive      Metro    60,347.00                     2
# 5  Tier 3  Executive      Metro    49,010.00                     2
# 6  Tier 3  Executive      Metro    57,879.00                     4
#
#   Graduation marks Exp (Months)           CTC
# 2               66           19    71,406.58
# 3               84           18    68,005.87
# 4               52           28    76,764.02
# 5               81           33    82,092.39
# 6               74           32    73,878.10

# %%
pip install wordcloud
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Kathir\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from wordcloud import WordCloud
text = " ".join(j for j in df['Role'])
word_cloud = WordCloud(collocations = False, background_color = 'black').generate(text)
plt.figure(figsize=[5,5])

plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
df['Previous job changes'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1['previous job changes'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='Role',y='previous CTC',data=df1,kind='bar')

# %%
sns.catplot(x='Role',y='Exp (Months)',data=df)

# %%
sns.distplot(df['Graduation marks'],kde=True)
plt.show()
# Out:
# C:\Users\Kathir\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Previous job changes'],kde=True)
plt.show()
# Out:
# C:\Users\Kathir\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1.plot(kind = 'box',layout=(3,3),subplots=True,figsize=[10,10])
# Out:
# College_T1                 AxesSubplot(0.125,0.657941;0.227941x0.222059)
# College_T2              AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Role_Manager            AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# City_Metro                 AxesSubplot(0.125,0.391471;0.227941x0.222059)
# previous CTC            AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# previous job changes    AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Graduation marks              AxesSubplot(0.125,0.125;0.227941x0.222059)
# Exp                        AxesSubplot(0.398529,0.125;0.227941x0.222059)
# Actual CTC                 AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %%
corr=df1.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)

# %%
df1.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC
# 0  71406.57653
# 1  68005.87063
# 2  76764.02028
# 3  82092.38688
# 4  73878.09773

# %%
df.dropna(inplace=True)

# %%
df1.drop(['College_T1','College_T2','Role_Manager','City_Metro'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#   College       Role  City type  previous CTC  previous job changes  \
# 0  Tier 1    Manager  Non-Metro         55523                     3
# 1  Tier 2  Executive      Metro         57081                     1
# 2  Tier 2  Executive      Metro         60347                     2
# 3  Tier 3  Executive      Metro         49010                     2
# 4  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp   Actual CTC
# 0                66   19  71406.57653
# 1                84   18  68005.87063
# 2                52   28  76764.02028
# 3                81   33  82092.38688
# 4                74   32  73878.09773

# %%
df['CTC']=df['CTC'].apply(lambda x: float(str(x).split()[0].replace(',', '')))
df1['Actual CTC']=df1['Actual CTC'].apply(lambda x: float(str(x).split()[0].replace(',', '')))
df['Previous CTC']=df['Previous CTC'].apply(lambda x: float(str(x).split()[0].replace(',', '')))
df1['previous CTC']=df1['previous CTC'].apply(lambda x: float(str(x).split()[0].replace(',', '')))

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['College']=le.fit_transform(df['College'])
df['Role']=le.fit_transform(df['Role'])
df['City type']=le.fit_transform(df['City type'])

# %%
df.head()
# Out:
#    College  Role  City type  Previous CTC Previous job changes  \
# 2        0     1          1       55523.0                    3
# 3        1     0          0       57081.0                    1
# 4        1     0          0       60347.0                    2
# 5        2     0          0       49010.0                    2
# 6        2     0          0       57879.0                    4
#
#   Graduation marks Exp (Months)       CTC
# 2               66           19  71406.58
# 3               84           18  68005.87
# 4               52           28  76764.02
# 5               81           33  82092.39
# 6               74           32  73878.10

# %%
df1['College']=le.fit_transform(df1['College'])
df1['Role']=le.fit_transform(df1['Role'])
df1['City type']=le.fit_transform(df1['City type'])

# %%
x=df.drop('CTC',axis=1).values
y=df['CTC'].values
x.reshape(-1,1)
y.reshape(-1,1)
# Out:
# array([[71406.58],
#        [68005.87],
#        [76764.02],
#        ...,
#        [66397.77],
#        [64044.38],
#        [83346.06]])

# %%
x.shape[0]
# Out:
# 1338

# %%
y.shape
# Out:
# (1338,)

# %%
len(x)==len(y)
# Out:
# True

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
rs.fit(x)
x1=rs.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x1,y,test_size=0.2,random_state=0)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_val)

# %%
pred
# Out:
# array([ 78757.42013653,  71423.38447046,  95214.51214143,  77668.05501749,
#         64834.50622792,  71885.45333629,  63788.29216686,  70847.6498696 ,
#         66201.92243053,  70362.24989581,  64059.08567783,  66792.83034641,
#         70253.58705573,  62927.17355453,  83815.95178691,  69205.95017926,
#         73110.78171793,  72704.7441837 ,  69502.2149931 ,  90864.59883336,
#         88282.38155972,  71207.20859817,  75868.0585306 ,  89424.00651448,
#         68507.49952174,  76560.88024919,  63306.02808026,  70848.83452865,
#         65895.22100751,  72572.41412991,  66204.28377057,  98867.98797474,
#         83512.78912912,  81467.71632825,  81381.03130863,  67205.70962325,
#         78801.5211272 ,  93445.19797272,  86488.16570654,  66503.10861363,
#         66678.02696469,  69168.95626564,  93656.25051273,  98761.09508549,
#         85460.15252578,  63233.39739606,  72291.38254429,  68043.18145486,
# ...

# %%
y_val
# Out:
# array([ 71105.71,  62426.39,  99734.64,  85083.58,  59721.74,  69525.33,
#         69764.49,  67273.98,  63921.31,  61396.48,  62314.99,  63263.77,
#         71532.81,  65377.42,  78089.72,  67402.38,  76284.19,  74544.57,
#         72441.01,  86581.05,  80430.97,  67700.67,  76674.92,  74594.62,
#         62356.93,  66943.01,  65494.51,  67427.14,  59950.89,  68928.96,
#         73281.55, 102928.71,  77770.17,  86354.84,  70469.63,  60154.54,
#         65882.77, 118651.89,  99227.71,  62180.74,  64269.18,  65685.02,
#         80856.11, 110438.17,  97119.39,  76976.49,  69960.25,  72634.98,
#         64636.87,  82368.08,  71112.14,  80699.82,  86487.58, 114939.65,
#         87222.87,  67244.5 ,  67929.18,  65581.33,  69919.87,  73051.32,
#         76382.82, 101108.86,  70999.92,  85719.27,  89189.31,  75572.88,
#         96401.16,  96427.67,  61314.49,  71232.98,  74265.4 ,  73990.76,
#         77569.74,  77986.3 ,  73639.06,  75668.6 ,  76451.55,  78002.78,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
print('r2 score is :',r2_score(y_val,pred))
# Out:
# r2 score is : 0.6594901891109096

# %%
print('MSE score is :',mean_squared_error(y_val,pred))
# Out:
# MSE score is : 58900778.4139097

# %%
rmse=np.sqrt(mean_squared_error(y_val,pred))
print(rmse)
# Out:
# 7674.684254997706

# %%
df1.head()
# Out:
#    College  Role  City type  previous CTC  previous job changes  \
# 0        0     1          1       55523.0                     3
# 1        1     0          0       57081.0                     1
# 2        1     0          0       60347.0                     2
# 3        2     0          0       49010.0                     2
# 4        2     0          0       57879.0                     4
#
#    Graduation marks  Exp   Actual CTC
# 0                66   19  71406.57653
# 1                84   18  68005.87063
# 2                52   28  76764.02028
# 3                81   33  82092.38688
# 4                74   32  73878.09773

# %%
x_test=df1.iloc[:,0:7].values
y_test=df1.iloc[:,-1].values

# %%
pred=lr.predict(x_test)
pred
# Out:
# C:\Users\Kathir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([2.18483795e+08, 2.24581891e+08, 2.37491781e+08, ...,
#        2.43758059e+08, 2.09354914e+08, 2.04181748e+08])
